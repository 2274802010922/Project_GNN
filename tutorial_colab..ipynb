# %%
# !rm -rf Project_GNN

# %%
# !pip install torch-geometric
# !pip install pyvis
# !pip install scikit-learn

# %%
# !git clone https://github.com/2274802010922/Project_GNN.git
# Out:
# Cloning into 'Project_GNN'...
# remote: Enumerating objects: 229, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 229 (delta 44), reused 0 (delta 0), pack-reused 150 (from 1)
# Receiving objects: 100% (229/229), 86.05 KiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# %cd Project_GNN
# Out:
# /content/Project_GNN

# %%
# !ls
# Out:
# dataset.py	      gnn_model.py	    main.py	      visualize.py
# explain.py	      graph_builder.py	    requirements.txt
# feature_extractor.py  interactive_graph.py  train.py

# %%
# !pip install -r requirements.txt

# %%
# !pip install torch-geometric --upgrade

# %%
# !pip install pyvis

# %%
import main
main.main()
# Out:
# ===== STEP 1: DOWNLOAD DATASET =====
# Using Colab cache for faster access to the 'vaipe-minimal-dataset' dataset.
# Dataset downloaded to: /kaggle/input/vaipe-minimal-dataset
#
# ===== STEP 2: EXTRACT FEATURES =====
# Total images: 99
#
# ===== STEP 3: BUILD GRAPH =====
# Nodes: 99
# Edges: 8
#
# ===== STEP 4: TRAIN GNN =====
# Epoch 1 Loss 2.3542
# Epoch 2 Loss 2.2140
# Epoch 3 Loss 2.1582
# Epoch 4 Loss 2.1144
# Epoch 5 Loss 2.0635
# Epoch 6 Loss 2.0078
# Epoch 7 Loss 1.9526
# Epoch 8 Loss 1.8987
# Epoch 9 Loss 1.8454
# Epoch 10 Loss 1.7915
# Epoch 11 Loss 1.7377
# Epoch 12 Loss 1.6835
# Epoch 13 Loss 1.6279
# Epoch 14 Loss 1.5697
# Epoch 15 Loss 1.5101
# Epoch 16 Loss 1.4493
# Epoch 17 Loss 1.3872
# Epoch 18 Loss 1.3253
# Epoch 19 Loss 1.2650
# Epoch 20 Loss 1.2036
# Epoch 21 Loss 1.1415
# Epoch 22 Loss 1.0809
# Epoch 23 Loss 1.0217
# Epoch 24 Loss 0.9623
# Epoch 25 Loss 0.9051
# Epoch 26 Loss 0.8489
# Epoch 27 Loss 0.7939
# Epoch 28 Loss 0.7415
# Epoch 29 Loss 0.6911
# ...
